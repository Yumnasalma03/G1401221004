# %% [markdown]
# <a href="https://colab.research.google.com/github/Yumnasalma03/G1401221004/blob/main/Tugas_2_Praktikum_TPM_Yumna_Salma.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Yumna Salma (G1401221004)**
#
# Tugas Mandiri 2 - Teknik Pembelajaran Mesin - Neural Network

# %%
import pandas as pd

# %% [markdown]
# # Input Data

# %%
data = pd.read_csv("/Pakistan house price dataset.csv", sep = ",")
data
# Out:
#         property_id  location_id  \
# 0            237062         3325
# 1            346905         3236
# 2            386513          764
# 3            656161          340
# 4            841645         3226
# ...             ...          ...
# 168441     17355248         6754
# 168442     17355249          680
# 168443     17355250         6757
# 168444     17355251         6752
# 168445     17355287        10045
#
#                                                  page_url property_type  \
# 0       https://www.zameen.com/Property/g_10_g_10_2_gr...          Flat
# 1       https://www.zameen.com/Property/e_11_2_service...          Flat
# 2       https://www.zameen.com/Property/islamabad_g_15...         House
# 3       https://www.zameen.com/Property/islamabad_bani...         House
# 4       https://www.zameen.com/Property/dha_valley_dha...         House
# ...                                                   ...           ...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168446 entries, 0 to 168445
# Data columns (total 20 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   property_id    168446 non-null  int64
#  1   location_id    168446 non-null  int64
#  2   page_url       168446 non-null  object
#  3   property_type  168446 non-null  object
#  4   price          168446 non-null  int64
#  5   location       168446 non-null  object
#  6   city           168446 non-null  object
#  7   province_name  168446 non-null  object
#  8   latitude       168446 non-null  float64
#  9   longitude      168446 non-null  float64
#  10  baths          168446 non-null  int64
#  11  area           168446 non-null  object
#  12  purpose        168446 non-null  object
#  13  bedrooms       168446 non-null  int64
#  14  date_added     168446 non-null  object
#  15  agency         124375 non-null  object
#  16  agent          124374 non-null  object
# ...

# %% [markdown]
# # Preproccessing Data

# %%
data.isnull().sum()
# Out:
# property_id          0
# location_id          0
# page_url             0
# property_type        0
# price                0
# location             0
# city                 0
# province_name        0
# latitude             0
# longitude            0
# baths                0
# area                 0
# purpose              0
# bedrooms             0
# date_added           0
# agency           44071
# agent            44072
# Area Type            0
# Area Size            0
# Area Category        0
# dtype: int64

# %% [markdown]
# Terdapat beberapa missing value pada variabel agency dan agent sebanyak 44071, sehingga diperlukan penanganan missing value dengan menghapus missing value tersebut

# %%
data = data.dropna()
data.isnull().sum()
# Out:
# property_id      0
# location_id      0
# page_url         0
# property_type    0
# price            0
# location         0
# city             0
# province_name    0
# latitude         0
# longitude        0
# baths            0
# area             0
# purpose          0
# bedrooms         0
# date_added       0
# agency           0
# agent            0
# Area Type        0
# Area Size        0
# Area Category    0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 124374 entries, 4 to 168445
# Data columns (total 20 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   property_id    124374 non-null  int64
#  1   location_id    124374 non-null  int64
#  2   page_url       124374 non-null  object
#  3   property_type  124374 non-null  object
#  4   price          124374 non-null  int64
#  5   location       124374 non-null  object
#  6   city           124374 non-null  object
#  7   province_name  124374 non-null  object
#  8   latitude       124374 non-null  float64
#  9   longitude      124374 non-null  float64
#  10  baths          124374 non-null  int64
#  11  area           124374 non-null  object
#  12  purpose        124374 non-null  object
#  13  bedrooms       124374 non-null  int64
#  14  date_added     124374 non-null  object
#  15  agency         124374 non-null  object
#  16  agent          124374 non-null  object
# ...

# %%
data.drop(columns=['property_id', 'location_id', 'page_url', 'date_added','location', 'latitude', 'area', 'agency', 'agent', 'Area Category','longitude'],
           inplace=True, errors='ignore')
print(data)
# Out:
#        property_type     price       city      province_name  baths   purpose  \
# 4              House   7000000  Islamabad  Islamabad Capital      3  For Sale
# 7               Flat   7800000  Islamabad  Islamabad Capital      2  For Sale
# 8              House  50000000  Islamabad  Islamabad Capital      7  For Sale
# 9          Penthouse  40000000  Islamabad  Islamabad Capital      5  For Sale
# 10              Flat  35000000  Islamabad  Islamabad Capital      3  For Sale
# ...              ...       ...        ...                ...    ...       ...
# 168441         House  26500000    Karachi              Sindh      0  For Sale
# 168442         House  12500000    Karachi              Sindh      0  For Sale
# 168443         House  27000000    Karachi              Sindh      0  For Sale
# 168444         House  11000000    Karachi              Sindh      0  For Sale
# 168445         House   9000000    Karachi              Sindh      3  For Sale
#
# ...

# %%
Pada bagian preproccessing di atas, telah dilakukan proses pembuangan peubah-peubah yang tidak diperlukan

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 124374 entries, 4 to 168445
# Data columns (total 9 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   property_type  124374 non-null  object
#  1   price          124374 non-null  int64
#  2   city           124374 non-null  object
#  3   province_name  124374 non-null  object
#  4   baths          124374 non-null  int64
#  5   purpose        124374 non-null  object
#  6   bedrooms       124374 non-null  int64
#  7   Area Type      124374 non-null  object
#  8   Area Size      124374 non-null  float64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 9.5+ MB

# %% [markdown]
# # Encoding Peubah Kategorik

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import SGD, Adam, RMSprop
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Mengonversi kategorik menjadi angka sebelum OHE
for col in data.select_dtypes(include=['object']):
    data[col] = data[col].astype('category').cat.codes

# One-Hot Encoding
for col in data.select_dtypes(include=['object']):
    data[col] = list(to_categorical(data[col]))

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 124374 entries, 4 to 168445
# Data columns (total 9 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   property_type  124374 non-null  int8
#  1   price          124374 non-null  int64
#  2   city           124374 non-null  int8
#  3   province_name  124374 non-null  int8
#  4   baths          124374 non-null  int64
#  5   purpose        124374 non-null  int8
#  6   bedrooms       124374 non-null  int64
#  7   Area Type      124374 non-null  int8
#  8   Area Size      124374 non-null  float64
# dtypes: float64(1), int64(3), int8(5)
# memory usage: 5.3 MB
# <ipython-input-12-246f739dffac>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %% [markdown]
# # Eksplorasi Data

# %%
num_cols = data.select_dtypes(include=["number"])

num_features = len(num_cols.columns)
rows = int(np.ceil(num_features / 2))

# Histogram untuk kolom numerik
fig, axes = plt.subplots(rows, 2, figsize=(12, 6 * rows))
axes = axes.flatten()

for i, col in enumerate(num_cols.columns):
    axes[i].hist(num_cols[col], bins=20, color="yellow", edgecolor="black")
    axes[i].set_title(col)
    axes[i].set_xlabel(col)

plt.tight_layout()
plt.show()

# Boxplot untuk kolom numerik
fig, axes = plt.subplots(rows, 2, figsize=(12, 6 * rows))
axes = axes.flatten()

for i, col in enumerate(num_cols.columns):
    axes[i].boxplot(num_cols[col], vert=False, patch_artist=True, boxprops=dict(facecolor="yellow"))
    axes[i].set_title(col)

plt.tight_layout()
plt.show()

# %% [markdown]
# Visualisasi sebaran data untuk setiap peubah menggunakan bar chart dan boxplot

# %%
num_cols = data.select_dtypes(include=[np.number]).columns
correlation_matrix = data[num_cols].corr()

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap="coolwarm", linewidths=0.5)

plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# Visualisasi hubungan antar peubah dengan matriks korelasi untuk melihat kekuatan hubungan antar peubah dan dihasilkan bahwa hubungan keseluruhan peubah dengan peubah lain selain dirinya terlihat tidak memiliki korelasi terlalu kuat.

# %% [markdown]
# # Splitting Data

# %%
data["harga"] = data["price"].apply(lambda x: "Murah" if x <= 17767764 else "Mahal")
# Out:
# <ipython-input-15-fbd8b1e0b0b2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["harga"] = data["price"].apply(lambda x: "Murah" if x <= 17767764 else "Mahal")

# %% [markdown]
# Sebelum dilakukan splitting data, dilakukan pembuatan kategori untuk peubah harga yang akan menjadi peubah target dengan membagi menjadi dua bagian berdasarkan rata-rata. Dua kategori tersebut antara lain, murah untuk rumah harga di bawah rata-rata dan mahal untuk harga rumah di atas rata-rata

# %%
data.drop(columns=['price'],
           inplace=True, errors='ignore')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 124374 entries, 4 to 168445
# Data columns (total 9 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   property_type  124374 non-null  int8
#  1   city           124374 non-null  int8
#  2   province_name  124374 non-null  int8
#  3   baths          124374 non-null  int64
#  4   purpose        124374 non-null  int8
#  5   bedrooms       124374 non-null  int64
#  6   Area Type      124374 non-null  int8
#  7   Area Size      124374 non-null  float64
#  8   harga          124374 non-null  object
# dtypes: float64(1), int64(2), int8(5), object(1)
# memory usage: 5.3+ MB
# <ipython-input-16-41b7b4e054c5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop(columns=['price'],

# %%
# Set seed untuk reproduktifitas
np.random.seed(123)

# Membagi data menjadi train dan test (70% train, 30% test)
train, test = train_test_split(data, test_size=0.3, stratify=data['harga'], random_state=123)

# Pisahkan fitur dan target
train_X = train.drop('harga', axis=1)
test_X = test.drop('harga', axis=1)
train_y = train['harga']
test_y = test['harga']

# Feature Scaling menggunakan Min-Max Scaler
scaler = MinMaxScaler()
train_X = scaler.fit_transform(train_X)
test_X = scaler.transform(test_X)

# OHE pada peubah target
train_y = to_categorical(train_y.astype('category').cat.codes)
test_y = to_categorical(test_y.astype('category').cat.codes)

# Output shape dari hasil encoding
print("Shape train_X:", train_X.shape)
print("Shape test_X:", test_X.shape)
print("Shape train_y:", train_y.shape)
print("Shape test_y:", test_y.shape)
# Out:
# Shape train_X: (87061, 8)
# Shape test_X: (37313, 8)
# Shape train_y: (87061, 2)
# Shape test_y: (37313, 2)

# %% [markdown]
# Kemudian, dilakukan pembagian data menjadi data test dan data train dengan bagian masing masing 70% data train dan 30% data test.

# %% [markdown]
# # Pemodelan ANN dengan 1 Hidden Layer

# %%
# Membuat model neural network dengan 1 hidden layer
model = Sequential([
    Dense(64, activation='relu', input_shape=(train_X.shape[1],)),  # Hidden Layer 1
    Dense(train_y.shape[1], activation='softmax')  # Output Layer
])

# Mengkompilasi model
model.compile(
    loss="categorical_crossentropy",
    optimizer="adam",
    metrics=["accuracy"]
)

# Menampilkan ringkasan model
model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 64)                  │             576 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 2)                   │             130 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
# ...

# %% [markdown]
# Model yang dibuat adalah Sequential, yang berarti lapisan (layer) disusun berurutan.
# Memiliki 1 hidden layer dengan 64 neuron dan fungsi aktivasi ReLU.
# Lapisan output memiliki 2 neuron, yang sesuai dengan jumlah kelas dalam klasifikasi kategori, dan menggunakan fungsi aktivasi Softmax.Parameter total sebanyak 706, menunjukkan model ringan dan tidak terlalu kompleks.
#
#
# *   Loss function: categorical_crossentropy, digunakan untuk klasifikasi kategori lebih dari 2 kelas (meskipun outputnya hanya 2, bisa jadi karena one-hot encoding).
# *   Optimizer: adam, yang merupakan optimasi adaptif berbasis gradien.

# %%
# Melatih model
history = model.fit(
    train_X, train_y,
    shuffle=True,
    epochs=100,
    batch_size=32,
    validation_split=0.2
)

# Menampilkan plot pembelajaran model pada setiap epoch
plt.figure(figsize=(10, 5))

# Plot loss
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training & Validation Loss')
plt.legend()

# Plot akurasi
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training & Validation Accuracy')
plt.legend()

plt.show()
# Out:
# Epoch 1/100
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.8134 - loss: 0.4028 - val_accuracy: 0.8696 - val_loss: 0.2936
# Epoch 2/100
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8708 - loss: 0.2907 - val_accuracy: 0.8807 - val_loss: 0.2660
# Epoch 3/100
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8860 - loss: 0.2636 - val_accuracy: 0.8824 - val_loss: 0.2553
# Epoch 4/100
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.8996 - loss: 0.2432 - val_accuracy: 0.9048 - val_loss: 0.2327
# Epoch 5/100
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9064 - loss: 0.2272 - val_accuracy: 0.9058 - val_loss: 0.2238
# Epoch 6/100
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9073 - loss: 0.2226 - val_accuracy: 0.8991 - val_loss: 0.2215
# Epoch 7/100
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9052 - loss: 0.2198 - val_accuracy: 0.8981 - val_loss: 0.2221
# Epoch 8/100
# ...

# %% [markdown]
# *   **Training and Validation Loss**
#
# Pada awal pelatihan, loss cukup tinggi, tetapi menurun dengan cepat selama beberapa epoch pertama.
# Setelah sekitar 20 epoch, loss menjadi lebih stabil dan terus menurun perlahan.
# Loss pada data validasi mengikuti pola yang serupa dengan training loss, tetapi dengan sedikit fluktuasi.
# Tidak ada tanda-tanda overfitting yang signifikan karena validation loss tidak meningkat drastis dibandingkan training loss.
# *   **Training and Validation Accuracy**
#
# Accuracy meningkat pesat dalam beberapa epoch pertama dan terus meningkat perlahan setelahnya.
# Training accuracy dan validation accuracy tetap berdekatan sepanjang proses pelatihan, menunjukkan bahwa model dapat melakukan generalisasi dengan baik terhadap data validasi.
# Meskipun validation accuracy sedikit lebih fluktuatif dibandingkan training accuracy, perbedaan ini masih dalam batas wajar.

# %%
# Mengevaluasi model menggunakan data uji
scores = model.evaluate(test_X, test_y)

# Menampilkan hasil evaluasi (loss dan accuracy)
print(f"Test Loss: {scores[0]:.4f}")
print(f"Test Accuracy: {scores[1]:.4f}")
# Out:
# 1167/1167 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9156 - loss: 0.1920
# Test Loss: 0.1957
# Test Accuracy: 0.9144

# %% [markdown]
# **Test Loss: 0.1957**
#
# Nilai loss pada data uji cukup rendah, menunjukkan bahwa model tidak mengalami overfitting yang signifikan dan dapat menggeneralisasi dengan baik terhadap data baru.
#
# **Test Accuracy: 0.9144**
#
# Akurasi pada data uji sebesar 91.44%, yang sangat dekat dengan akurasi validasi.
# Hal ini menunjukkan bahwa model bekerja dengan baik pada data yang belum pernah dilihat sebelumnya, yang menandakan generalisasi yang baik.

# %% [markdown]
# #  Pemodelan ANN dengan 2 Hidden Layer dan Dropout

# %%
# Membuat model neural network dengan 2 hidden layer
model = Sequential([
    Dense(128, activation='relu', input_shape=(train_X.shape[1],)),  # Hidden Layer 1
    Dropout(0.2),
    Dense(64, activation='relu'),  # Hidden Layer 2
    Dropout(0.2),
    Dense(train_y.shape[1], activation='softmax')  # Output Layer
])

# Mengkompilasi model
model.compile(
    loss="categorical_crossentropy",
    optimizer="adam",
    metrics=["accuracy"]
)

# Menampilkan ringkasan model
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_2 (Dense)                      │ (None, 128)                 │           1,152 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 64)                  │               0 │
# ...

# %% [markdown]
# Pemodelan ANN 2 hidden layer menunjukkan
#
# **Layer 1 (Hidden Layer 1):**
#
# Dense (128 neurons, ReLU activation) → Berfungsi untuk menangkap pola kompleks dalam data.
# Dropout (0.2) → Mengurangi kemungkinan overfitting dengan mengabaikan 20% dari neuron selama training.
#
#
# **Layer 2 (Hidden Layer 2):**
#
# Dense (64 neurons, ReLU activation) → Lapisan kedua yang mengurangi dimensi dari 128 ke 64 untuk menangkap informasi yang lebih relevan.
# Dropout (0.2) → Regularisasi lebih lanjut untuk mencegah overfitting.
#
# **Output Layer:**
#
# Dense (2 neurons, Softmax activation) → Lapisan terakhir dengan 2 neuron (karena klasifikasi kategori), menggunakan softmax untuk mendapatkan probabilitas kelas.
#
# **Total Parameters: 9,538**
# Jumlah parameter ini meningkat dibandingkan model sebelumnya dengan 1 hidden layer, karena lebih banyak neuron digunakan.

# %%
# Melatih model
history = model.fit(
    train_X, train_y,
    shuffle=True,
    epochs=50,
    batch_size=32,
    validation_split=0.2,
    verbose=0  # Tidak menampilkan output setiap epoch
)

# Menampilkan ringkasan model
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_2 (Dense)                      │ (None, 128)                 │           1,152 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 64)                  │               0 │
# ...

# %%
# Menampilkan plot pembelajaran model pada setiap epoch
plt.figure(figsize=(10, 5))

# Plot loss
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training & Validation Loss')
plt.legend()

# Plot akurasi
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training & Validation Accuracy')
plt.legend()

plt.show()

# %% [markdown]
# **Training Loss dan Validation Loss** *menurun* seiring waktu.Pada awal training, loss turun dengan cepat, lalu stabil setelah sekitar epoch ke-10.Tidak ada tanda-tanda overfitting yang jelas, karena validation loss tetap sejalan dengan training loss tanpa mengalami kenaikan yang tajam. **Akurasi training dan validasi** *meningkat* seiring epoch.
# Pada awalnya, validasi akurasi fluktuatif tetapi tetap sejalan dengan akurasi training.
# Setelah epoch ke-20, *akurasi training stabil* di sekitar *91%*, dengan validasi akurasi berfluktuasi namun tetap dalam rentang yang sama.

# %%
# Mengevaluasi model menggunakan data uji
scores = model.evaluate(test_X, test_y, verbose=0)  # verbose=0 untuk menyembunyikan output evaluasi

# Menampilkan hasil evaluasi (loss dan accuracy)
print(f"Test Loss: {scores[0]:.4f}")
print(f"Test Accuracy: {scores[1]:.4f}")
# Out:
# Test Loss: 0.1979
# Test Accuracy: 0.9069

# %% [markdown]
# Loss cukup rendah (0.1979), menunjukkan bahwa model tidak terlalu banyak melakukan kesalahan pada data uji. Akurasi cukup tinggi (90.69%), yang berarti model mampu mengklasifikasikan data uji dengan baik.Performa model pada data uji cukup sejalan dengan data validasi (berkisar di angka 90%-91%), menunjukkan tidak ada overfitting yang signifikan.

# %% [markdown]
# # Pemodelan Tuning Optimizer

# %%
# Parameter model
input_dim = train_X.shape[1]  # Jumlah fitur input
output_dim = train_y.shape[1] # Jumlah kelas output

# Daftar optimizer yang akan diuji
optimizers = {
    "SGD": SGD(learning_rate=0.01),
    "Momentum_SGD": SGD(learning_rate=0.01, momentum=0.9),
    "Adam": Adam(learning_rate=0.01),
    "RMSprop": RMSprop(learning_rate=0.01)
}

# Fungsi untuk membuat model dengan optimizer tertentu
def create_model(optimizer):
    model = Sequential([
        Dense(64, activation="relu", input_shape=(input_dim,)),  # Hidden Layer 1
        Dense(output_dim, activation="softmax")  # Output Layer
    ])

    model.compile(
        loss="categorical_crossentropy",
        optimizer=optimizer,
        metrics=["accuracy"]
    )

    model.summary()  # Menampilkan arsitektur model

    return model

# Fungsi untuk melatih model dan menyimpan histori loss & akurasi
def train_and_evaluate(optimizer_name, optimizer):
    model = create_model(optimizer)

    history = model.fit(
        train_X, train_y,
        shuffle=True,
        epochs=100,
        batch_size=32,
        validation_split=0.2,
        verbose=0
    )

    # Simpan hasil training
    results = pd.DataFrame({
        "optimizer": [optimizer_name] * 100,
        "epoch": list(range(1, 101)),
        "loss": history.history["val_loss"],
        "accuracy": history.history["val_accuracy"]
    })

    return {"model": model, "results": results}

# %%
# Jalankan training untuk setiap optimizer
models_results = [train_and_evaluate(name, optimizers[name]) for name in optimizers]

# Menggabungkan hasil training dari semua optimizer
results = pd.concat([res["results"] for res in models_results], ignore_index=True)

# Menyimpan model yang telah dilatih
models = {name: res["model"] for name, res in zip(optimizers.keys(), models_results)}

# Plot perbandingan loss antar optimizer
plt.figure(figsize=(10, 5))
sns.lineplot(data=results, x="epoch", y="loss", hue="optimizer")
plt.title("Perbandingan Optimizer: Loss")
plt.xlabel("Epoch")
plt.ylabel("Validation Loss")
plt.legend(title="Optimizer")
plt.show()

# Plot perbandingan akurasi antar optimizer
plt.figure(figsize=(10, 5))
sns.lineplot(data=results, x="epoch", y="accuracy", hue="optimizer")
plt.title("Perbandingan Optimizer: Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Validation Accuracy")
plt.legend(title="Optimizer")
plt.show()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_5 (Dense)                      │ (None, 64)                  │             576 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 2)                   │             130 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 706 (2.76 KB)
#  Trainable params: 706 (2.76 KB)
#  Non-trainable params: 0 (0.00 B)
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ...

# %%
# Mengevaluasi setiap model dengan data uji dan menyimpan hasilnya
evaluation_results = {}

for name, model in models.items():
    scores = model.evaluate(test_X, test_y, verbose=0)  # Evaluasi model
    evaluation_results[name] = {"Test Loss": scores[0], "Test Accuracy": scores[1]}

# Menampilkan hasil evaluasi untuk setiap optimizer
for name, result in evaluation_results.items():
    print(f"Optimizer: {name}")
    print(f"Test Loss: {result['Test Loss']:.4f}")
    print(f"Test Accuracy: {result['Test Accuracy']:.4f}")
    print("-" * 30)
# Out:
# Optimizer: SGD
# Test Loss: 0.2800
# Test Accuracy: 0.8773
# ------------------------------
# Optimizer: Momentum_SGD
# Test Loss: 0.2330
# Test Accuracy: 0.8987
# ------------------------------
# Optimizer: Adam
# Test Loss: 0.1972
# Test Accuracy: 0.9169
# ------------------------------
# Optimizer: RMSprop
# Test Loss: 0.2141
# Test Accuracy: 0.9113
# ------------------------------

# %% [markdown]
# **Adam dan RMSprop** memberikan hasil terbaik dalam hal akurasi dan loss. Adam dengan akurasi 91.69%, Loss 0.1972 dan RMSprop akurasi 91.13%, Loss 0.2141.

# %% [markdown]
# # Pemodelan Tuning Learning Rate

# %%
# Daftar learning rate yang akan diuji
learning_rates = [0.0001, 0.001, 0.01, 0.1]

# Fungsi untuk membuat model dengan learning rate tertentu
def create_model(learning_rate):
    model = Sequential([
        Dense(64, activation="relu", input_shape=(input_dim,)),  # Hidden Layer
        Dense(output_dim, activation="softmax")  # Output Layer
    ])

    optimizer = Adam(learning_rate=learning_rate)

    model.compile(
        loss="categorical_crossentropy",
        optimizer=optimizer,
        metrics=["accuracy"]
    )

    return model

# Fungsi untuk melatih model dan menyimpan hasil
def train_and_evaluate(lr_name, learning_rate):
    model = create_model(learning_rate)

    history = model.fit(
        train_X, train_y,
        shuffle=True,
        epochs=100,
        batch_size=32,
        validation_split=0.2,
        verbose=0
    )

    # Simpan hasil training dan validasi dalam DataFrame
    results = pd.DataFrame({
        "learning_rate": [lr_name] * 100,
        "epoch": list(range(1, 101)),
        "train_loss": history.history["loss"],
        "val_loss": history.history["val_loss"],
        "train_accuracy": history.history["accuracy"],
        "val_accuracy": history.history["val_accuracy"]
    })

    return {"model": model, "history": results}

# %%
# Menyimpan hasil training dan model untuk setiap learning rate
results_list = {}
models = {}

for lr in learning_rates:
    lr_name = f"lr_{lr}"  # Contoh nama model: lr_0.001
    train_result = train_and_evaluate(lr_name, lr)

    models[lr_name] = train_result["model"]  # Simpan model
    results_list[lr_name] = train_result["history"]  # Simpan hasil training

# Gabungkan semua hasil training ke dalam satu dataframe
results = pd.concat(results_list.values(), ignore_index=True)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Dapatkan daftar unique learning rate
unique_lrs = results["learning_rate"].unique()

# Buat subplot dengan 2 baris, 2 kolom
fig, axes = plt.subplots(2, 2, figsize=(14, 10))
axes = axes.flatten()  # Flatten agar lebih mudah diakses dengan loop

# Loop untuk membuat grafik Loss per learning rate
for i, lr in enumerate(unique_lrs):
    subset = results[results["learning_rate"] == lr]

    sns.lineplot(ax=axes[i], data=subset, x="epoch", y="train_loss", label="Train Loss", linestyle="dashed")
    sns.lineplot(ax=axes[i], data=subset, x="epoch", y="val_loss", label="Validation Loss")

    axes[i].set_title(f"Learning Rate: {lr}")
    axes[i].set_xlabel("Epoch")
    axes[i].set_ylabel("Loss")
    axes[i].legend()

plt.suptitle("Perbandingan Loss (Train vs Validation) untuk Setiap Learning Rate", fontsize=14)
plt.tight_layout()
plt.show()

# Buat subplot dengan 2 baris, 2 kolom untuk Accuracy
fig, axes = plt.subplots(2, 2, figsize=(14, 10))
axes = axes.flatten()

# Loop untuk membuat grafik Accuracy per learning rate
for i, lr in enumerate(unique_lrs):
    subset = results[results["learning_rate"] == lr]

    sns.lineplot(ax=axes[i], data=subset, x="epoch", y="train_accuracy", label="Train Accuracy", linestyle="dashed")
    sns.lineplot(ax=axes[i], data=subset, x="epoch", y="val_accuracy", label="Validation Accuracy")

    axes[i].set_title(f"Learning Rate: {lr}")
    axes[i].set_xlabel("Epoch")
    axes[i].set_ylabel("Accuracy")
    axes[i].legend()

plt.suptitle("Perbandingan Akurasi (Train vs Validation) untuk Setiap Learning Rate", fontsize=14)
plt.tight_layout()
plt.show()

# %%
# Evaluasi setiap model pada data uji
for lr_name, model in models.items():
    scores = model.evaluate(test_X, test_y, verbose=0)  # Evaluasi model
    print(f"{lr_name}:")
    print(f"  - Test Loss: {scores[0]:.4f}")
    print(f"  - Test Accuracy: {scores[1]:.4f}")
    print("-" * 40)
# Out:
# lr_0.0001:
#   - Test Loss: 0.2113
#   - Test Accuracy: 0.9050
# ----------------------------------------
# lr_0.001:
#   - Test Loss: 0.1953
#   - Test Accuracy: 0.9186
# ----------------------------------------
# lr_0.01:
#   - Test Loss: 0.1978
#   - Test Accuracy: 0.9130
# ----------------------------------------
# lr_0.1:
#   - Test Loss: 0.2635
#   - Test Accuracy: 0.8887
# ----------------------------------------

# %% [markdown]
# Learning rate **0.001 memberikan hasil terbaik**, dengan Test Accuracy 91.86% dan Test Loss 0.1953. Learning rate **0.01 juga cukup baik**, dengan akurasi 91.30%, meskipun sedikit lebih rendah dari 0.001.

# %% [markdown]
# # Menghasilkan Prediksi

# %%
# Melakukan prediksi pada data uji
prediksi = models["lr_0.01"].predict(test_X)
print(prediksi[:5])  # Menampilkan 5 prediksi pertama
# Out:
# 1167/1167 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step
# [[1.2035244e-01 8.7964755e-01]
#  [1.8515985e-25 9.9999994e-01]
#  [1.7796995e-01 8.2203013e-01]
#  [1.3244410e-15 9.9999994e-01]
#  [6.4340043e-01 3.5659945e-01]]

# %%
# Mengonversi kategorik menjadi angka sebelum OHE
for col in data.select_dtypes(include=['object']):
    data[col] = data[col].astype('category').cat.codes

# One-Hot Encoding
for col in data.select_dtypes(include=['object']):
    data[col] = list(to_categorical(data[col]))

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 124374 entries, 4 to 168445
# Data columns (total 9 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   property_type  124374 non-null  int8
#  1   city           124374 non-null  int8
#  2   province_name  124374 non-null  int8
#  3   baths          124374 non-null  int64
#  4   purpose        124374 non-null  int8
#  5   bedrooms       124374 non-null  int64
#  6   Area Type      124374 non-null  int8
#  7   Area Size      124374 non-null  float64
#  8   harga          124374 non-null  int8
# dtypes: float64(1), int64(2), int8(6)
# memory usage: 4.5 MB

# %%
# Konversi probabilitas ke label kelas tertinggi (argmax)
label_pred = np.argmax(prediksi, axis=1)

# Label sebenarnya dari dataset
label_true = test["harga"].map({"Murah": 0, "Mahal": 1}).astype(int)

# %% [markdown]
# # Evaluasi Model

# %%
# Menampilkan confusion matrix
cm = confusion_matrix(label_true, label_pred)
print("Confusion Matrix:\n", cm)
# Out:
# Confusion Matrix:
#  [[ 1571 24763]
#  [ 9304  1675]]

# %% [markdown]
# * True Positives (TP) = 1675 Model memprediksi positif dengan benar.
# * False Positives (FP) = 24763 Model memprediksi positif, tetapi sebenarnya negatif.
# * False Negatives (FN) = 9304 Model memprediksi negatif, tetapi sebenarnya positif.
# * True Negatives (TN) = 1571 Model memprediksi negatif dengan benar.

# %%
# Menampilkan classification report (precision, recall, f1-score)
print("\nClassification Report:\n", classification_report(label_true, label_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.14      0.06      0.08     26334
#            1       0.06      0.15      0.09     10979
#
#     accuracy                           0.09     37313
#    macro avg       0.10      0.11      0.09     37313
# weighted avg       0.12      0.09      0.09     37313

# %%
# Mengevaluasi model menggunakan data uji
scores = models["lr_0.01"].evaluate(test_X, test_y, verbose=0)
print(f"\nTest Loss: {scores[0]:.4f}")
print(f"Test Accuracy: {scores[1]:.4f}")
# Out:
# Test Loss: 0.1978
# Test Accuracy: 0.9130

# %% [markdown]
# Akurasi di atas 90% menandakan bahwa model mampu mengenali pola dengan baik dan nilai loss yang cukup kecil menunjukkan bahwa model tidak mengalami overfitting yang parah.

# %% [markdown]
# # Menyimpan dan Membuat Model

# %%
# Menyimpan model dalam format HDF5
models["lr_0.01"].save("model_nn_sgd.h5")

# Memuat model dari file HDF5
new_model = load_model("model_nn_sgd.h5")

# Kompilasi ulang sebelum evaluasi
new_model.compile(
    optimizer="adam",
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

# Menampilkan arsitektur model yang dimuat
new_model.summary()
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Model: "sequential_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_17 (Dense)                     │ (None, 64)                  │             576 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# ...

# %% [markdown]
# Model yang telah dibuat, dapat disimpan ke dalam format HDF5 menggunakan fungsi save_model_hdf5. Selanjutnya untuk memuat model dapat menggunakan fungsi load_model_hdf5. Model yang sudah dimuat, dapat digunakan untuk memprediksi data baru menggunakan fungsi predict ataupun dapat juga melakukan proses re-train model dengan data baru menggunakan fungsi fit.
